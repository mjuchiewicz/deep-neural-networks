# %% [markdown]
# # Wstęp
#
# Na poprzednich zajęciach nauczyłeś(aś) się jak skonstruować od zera podstawową komórkę sieci neuronowej - Perceptron. Na tych zajęciach przejdziemy już do wykorzystywania bardziej zaawansowanych funkcji PyTorcha, które przydają się na codzień do konstruowania sieci neuronowych.
#
# ## Cel ćwiczenia
#
# Celem ćwiczenia jest zapoznanie z podstawowymi funkcjami biblioteki PyTorch do tworzenia i uczenia sieci neuronowych a w szczególności z:
# *   Automatycznym liczeniem gradientów i grafem obliczeniowym (autograd)
# *   Algorytmami off-line, on-line a także pojęciem mini-batch
# *   Algorytmami optymalizacji sieci neuronowych
# *   Liczeniem wartości fuknkcji straty
# *   Przekształceniami nieliniowymi
# *   Modułem `torch.nn`
#
# ## Warunki zaliczenia
#
# W celu zaliczenia ćwiczeń należy uzupełnić wszystkie brakujące elementu kodu, wykonać wszystkie polecenia i wyuczyć model.

# %%
import math
import warnings
from typing import Tuple

import torch
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from torch import nn
from torch import optim
from torch.utils.data import TensorDataset, DataLoader

assert torch.cuda.is_available(), "Uruchom środowisko wykonawcze na GPU"

# %% [markdown]
# # Autograd - automatyczne liczenie gradientów
#
# Na poprzednich laboratoriach implementowałeś(aś) funkcję wstecznej propagacji. W tym celu liczyłaś(eś) pochodne (gradienty). Przyjrzyjmy się najpierw funkcji
# $$f(x, y) = 3x^2 + y^3$$
# Możemy tę funkcję różniczkować po dwóch zmiennych: $x$ i $y$:
# $$\frac{\partial f}{\partial x} = 6x$$
#
# $$\frac{\partial f}{\partial y} = 3y^2$$
#
# Jeżeli funkcję $f(x,y)$ złożymy z funkcją $g(x) = x^2$ tworząc funkcję $h(x, y) = f(g(x), y)$ to z **reguły łańcuchowej** pochodna takiej funkcji wyniesie:
#
# $$\frac{\partial h}{\partial x} = \frac{\partial f}{\partial g} \frac{\partial g}{\partial x} = (6 (x^2)) (2 x) = 12 x^3$$
#
# Tego typu obliczenia przy wielu warstwach sieci (a więc przy wielu złożeniach funkcji liniowych i nieliniowych) stają się mocno skomplikowane. Na szczęście PyToch dostarcza `torch.autograd` - silnik do zaumatyzowanego liczenia gradientów. Jak on działa? Najpierw zdefiniujmy wektory $\mathbf x$ i $\mathbf y$.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

# %% [markdown]
# Zauważ, że tworząc tensor przekazaliśmy parametr `requires_grad=True`. Sprawia on, że wszystkie operacje dokonane na tym tensorze są śledzone i tensor wynikowy będzie "pamiętał" przy użyciu jakiej operacji powstał. Policzmy naszą funkcję $f( \mathbf x, \mathbf y)$ dla tych tensorów.

# %%
z = 3*x**2 + y**3
z
# Out:
# tensor([512.,  11., 139.], grad_fn=<AddBackward0>)

# %% [markdown]
# Jak widać uzyskany tensor ma także zapisany parametr `grad_fn=<AddBackward0>`, czyli że powstał z dodania dwóch tensorów - dodawanie jest ostatnią operacją, która zostałą wykonana, żeby otrzymać ten tensor. Dokonajmy propagacji wstecznej w celu policzenia gradientów.

# %%
grad_tensors = torch.tensor([1., 1., 1.])
z.backward(grad_tensors)
print(x.grad == 6*x)
print(y.grad == 3*y**2)
# Out:
# tensor([True, True, True])
# tensor([True, True, True])

# %% [markdown]
# Na razie nie przejmuj się tym za co odpowiada `grad_tensors`. Policzmy wartość funkcji $h$.

# %%
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
print(x.grad == 12*(x**3))
# Out:
# tensor([   0.,   18., 1530.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)
# tensor([ True, False, False])

# %% [markdown]
# Nie zgadzają nam się wartości. Wynika to z kolejnej właśności pytorchowego autograda - gradienty w tensorach są **akumulowane**. Jak wykonasz powyższą komórkę wielekrotnie to zobaczysz że wartości `x.grad` rosną dokładnie o $12x_i^3$ po każdym wykonaniu. Akumulacja gradientów jest przydatna w niektórych architekturach sieci neuronowych. Dlatego też trzeba *explicite* wyzerować gradienty.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Ok, powróćmy teraz do `grad_tensors` - co to jest? Otóż autograd jest silnikiem, który służy do wyliczania **macierzy Jacobiego**, tj. pochodnych pierwszego rzędu funkcji, których składowymi są funkcje rzeczywiste.
#
# $$f = (f_1, f_2, \ldots, f_m)$$
# $$\mathbf x = (x_1, x_2, \ldots, x_n)$$
#
# $$\mathbf J = \begin{bmatrix}
#  \dfrac{\partial f_1}{\partial x_1} & \cdots & \dfrac{\partial f_1}{\partial x_n} \\
#  \vdots & \ddots & \vdots \\
#  \dfrac{\partial f_m}{\partial x_1} & \cdots & \dfrac{\partial f_m}{\partial x_n}
# \end{bmatrix}$$
#
# Konkretnie patrząc na przykład z tensorem $a$ macierz Jacobiego wygląda tak:
# $$\mathbf J_a = \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} \\
#   \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_2}{\partial x_3} \\
#    \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}$$
#
# Następnie `grad_tensors` ($\mathbf z$) mnożymy przez transpozycję tej macierzy (ang. *Jacobian-vector product*).
#
# $$ \mathbf z \mathbf J_a^T = \begin{bmatrix} 1 & 1 & 1 \end{bmatrix}
# \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_3}{\partial x_1} \\
#   \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_2} \\
#    \dfrac{\partial a_1}{\partial x_3} & \dfrac{\partial a_2}{\partial x_3} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}
# = \begin{bmatrix} 1\dfrac{\partial a_1}{\partial x_1} + 1\dfrac{\partial a_1}{\partial x_2} + 1\dfrac{\partial a_1}{\partial x_3} & 1\dfrac{\partial a_2}{\partial x_1} + 1\dfrac{\partial a_2}{\partial x_2} + 1\dfrac{\partial a_2}{\partial x_3} & 1\dfrac{\partial a_3}{\partial x_1} + 1\dfrac{\partial a_3}{\partial x_2} + 1\dfrac{\partial a_3}{\partial x_3} \end{bmatrix}
# = \begin{bmatrix} 12(0)^3 + 0 + 0 & 0 + 12(1)^3 + 0 & 0 + 0 + 12(5)^3 \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix}$$
#
# Uzyskujemy te same gradienty co policzyliśmy dla wektora $\mathbf x$. Zamiast przekazywać wektor jedynek do `backward()`, można najpierw policzyć sumę wektora $\mathbf a$ a potem wykonać propagację wsteczną.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.sum().backward()
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Wtedy pamiętając o tym, że pochodna sumy to suma pochodnych ($(f(x) + g(x))' = f'(x) + g'(x)$):
#
# $$\begin{bmatrix}
#  \dfrac{\partial a}{\partial x_1} & \dfrac{\partial a}{\partial x_2} & \dfrac{\partial a}{\partial x_3}
# \end{bmatrix} = \begin{bmatrix} \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_1} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_2} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} + \dfrac{\partial a_2}{\partial x_1} + \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} + \dfrac{\partial a_2}{\partial x_2} + \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} + \dfrac{\partial a_2}{\partial x_3} + \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix} $$
#
# Zatem po co w ogóle ten wektor? Otóż służy on do przekazywania wektora gradientu funkcji straty ($\dfrac{\partial \mathbf{loss}}{\partial \mathbf y}$) lub "warstwy" wcześniejszej w obliczenich ($\dfrac{\partial \mathbf{f}}{\partial \mathbf y}$). Przeanalizumy to na przykładzie z funkcjami $f$, $g$, i $h$, które zaprezentowaliśmy wcześniej omawiając regułę łańcuchową.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

h.sum().backward()
h_grad = h.grad
g_grad = g.grad
h.grad, g.grad, x.grad, y.grad
# Out:
# (tensor([1., 1., 1.]),
#  tensor([  0.,   6., 150.]),
#  tensor([   0.,   12., 1500.]),
#  tensor([192.,  12.,  48.]))

# %% [markdown]
# Wykorzystaliśmy `retain_grad()`, żeby zapamiętać gradienty w tensorach pośrednich - domyślnie PyTorch nie zapamiętuje tych gradientów, aby [oszczędzić pamięć](https://discuss.pytorch.org/t/why-cant-i-see-grad-of-an-intermediate-variable/94/2). Zauważ, że:
#
#
# *   `h.grad` zawiera wektor jedynek;
# *   `g.grad` zawiera wartości pochodnej funkcji $f$ ($\frac{\partial f}{\partial x} = 6$);
# *   `x.grad` zawiera wartości pochodnej funkcji $h$ ($\frac{\partial h}{\partial x} = 12x^3$)
# *   `y.grad` zawiera wartości pochodnej funkcji $h$ ($\frac{\partial h}{\partial y} = \frac{\partial f}{\partial y} = 3y^2$).
#
# To teraz somodzielnie oddtworzymy działanie funkcji `backward()` wykrozystując gradienty pośrednie z wektorów $\mathbf g$ i $\mathbf h$.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

h.backward(h_grad)
# h.sum().backward()
h.grad, g.grad, x.grad, y.grad
# Out:
# (tensor([1., 1., 1.]),
#  tensor([  0.,   6., 150.]),
#  tensor([   0.,   12., 1500.]),
#  tensor([192.,  12.,  48.]))

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

g = x**2
h = 3*g**2 + y**3
g.retain_grad()
h.retain_grad()

g.backward(g_grad)
# h.backward(h_grad)
# h.sum().backward()
h.grad, g.grad, x.grad, y.grad
# Out:
# (None, tensor([  0.,   6., 150.]), tensor([   0.,   12., 1500.]), None)

# %% [markdown]
# Jak widać uzyskaliśmy te same gradienty wektora $\mathbf x$ przechodząc po grafie obliczeń "ręcznie" oraz przekazując odpowiednie gradienty w parametrze `grad_tensors`. No właśnie, wspomnieliśmy "graf obliczeń" - o co chodzi?

# %% [markdown]
# ## Graf obliczeniowy
#
# To wszystko jest możliwe dzięki temu, że autograd tworzy **acykliczny skierowany graf obilczeniowy**. Gdzie go przechowuje? Spójrzmy jeszcze raz na nasz wektor $\mathbf a$.

# %%
print(a)
print(a.grad_fn.next_functions)
# Out:
# tensor([ 512.,   11., 1939.], grad_fn=<AddBackward0>)
# ((<MulBackward0 object at 0x78b3570ef8b0>, 0), (<PowBackward0 object at 0x78b3570ef5e0>, 0))

# %% [markdown]
# Obiekt a ma pole `grad_fn` a ono ma pole `next_functions`. Widzimy, że $\mathbf a$ powstało z przemnożenia dwóch tensorów, gdzie pierwszy tensor był wynikiem mnożenia a drugi - potęgowania. A więc na razie wiemy, że `a = (_*_) + (_**_)`. I kolejno przechodząc po tym grafie możemy dalej odkrywać jego strukturę i jaka droga skonstruowania $\mathbf a$ się za nim kryje.

# %%
print(a.grad_fn.next_functions[0][0].next_functions) # a = ((_**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions) # a = (((_**_))**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions[0][0].next_functions) # a = (((x**_))**_))*_) + (_**_)
print()
print(a.grad_fn.next_functions[1][0].next_functions) # a = (((x**_))**_))*_) + (y**_)
# Out:
# ((<PowBackward0 object at 0x78b3570ee4a0>, 0), (None, 0))
# ((<PowBackward0 object at 0x78b3572b39a0>, 0),)
# ((<AccumulateGrad object at 0x78b3572b39a0>, 0),)
#
# ((<AccumulateGrad object at 0x78b3572b39a0>, 0),)

# %% [markdown]
# Po chwilii analizy można dostrzec że ta strutura odpowiada obliczeniu tensora $a$ ze wzoru $3(\mathbf x^2)^2 + \mathbf y^3$.
#
# Jeszcze warto wspomnieć o tym, że PyTorch śledzi to dla których tensorów trzeba tworzyć ten graf a dla których nie. Dlatego też jeżeli w operacjach użyjemy tensora, który "wymaga gradientu" (`requires_grad=True`) to uzyskamy tensor "wymagający gradientu":

# %%
x = torch.tensor([1., 2., 3.])
y = torch.tensor([6., 7., 8.])
z = torch.tensor([9., 7., 8.], requires_grad=True)
print((2*x + 3**y).requires_grad)
print((2*x + 3**y + z).requires_grad)
# Out:
# False
# True

# %% [markdown]
# Dla chcących dowiedzieć się czegoś więcej o mechanizmach autograda polecamy: [1](https://www.cs.toronto.edu/~rgrosse/courses/csc321_2018/slides/lec10.pdf), [2](https://github.com/mattjj/autodidact/).

# %% [markdown]
# # Refatoring kodu z laboratorium 2
#
# W tej części laboratorium dokonasz refaktoringu kodu z laboratorium drugiego z wykorzystaniem gotowych rozwiązań w bibliotece `torch` a w szczególności w `torch.nn`. Najpierw zacznijmy od załadowania zbioru danych i podzielenia go na zbiór uczący i testowy.

# %%
X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

X_train = torch.tensor(X_train).float().cuda()
X_test = torch.tensor(X_test).float().cuda()
y_train = torch.tensor(y_train).cuda()
y_test = torch.tensor(y_test).cuda()

y_test
# Out:
# tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1, 1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0,
#         0, 1, 2, 1, 1, 1, 2, 1, 0, 0, 1, 1], device='cuda:0')

# %% [markdown]
# ## `nn.Module` oraz `CrossEntropyLoss`
#
# Na poprzednich laboratoriach w tym miejscu implementowaliśmy funkcję sigmoid, inicjalizację parametrów oraz propagację w przód i wsteczną. Tym razem nie będzie trzeba tego robić, jednakże zdefiniujesz architekturę sieci przy użyciu modułu `torch.nn`.
#
# ***Zaimplementuj*** klasę Perceptron - klasę dziedziczącą po `nn.Module` z jedną warstwą transformacji liniowej (Perceptrona, [`torch.nn.Linear`](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)). Na razie ***pomiń*** transformację nieliniową (np. sigmoid).

# %%
class Perceptron(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Linear(4, 3)

    def forward(self, x: torch.Tensor):
        return self.net(x)

# %% [markdown]
# Wspominmy tylko, że można nadal używać `torch.nn` i nie wykorzystywać gotowych warstw sieci tylko samemu implementować operacje na tensorach:
#
# ```
# class Perceptron(nn.Module):
#     def __init__(self, in_dim: int, out_dim: int):
#         super().__init__()
#         self.weights = nn.Parameter(
#           torch.randn(in_dim, out_dim) / math.sqrt(in_dim)
#         )
#         self.bias = nn.Parameter(torch.zeros(out_dim))
#
#     def forward(self, xb: torch.Tensor):
#         return xb @ self.weights + self.bias
# ```
# ***Przetestuj*** poprawność swojej implementacji.

# %%
model = Perceptron().cuda()
y_pred_0 = model(X_train[0])
print(y_pred_0)

assert isinstance(y_pred_0, torch.cuda.FloatTensor)
assert len(y_pred_0) == 3
# Out:
# tensor([-4.3896,  4.2225, -1.8585], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# Wykorzystanie `nn.Linear` nie tylko odciążyło nas z implementacji operacji na tensorasch, ale także z inicjalizacji paprametrów modelu - inicjalizacja parametrów jest domyślnie implementowana przez daną wartstwę. Jeżeli uruchomisz powyższy kod wielokrotnie to zauważysz, że za każdym razem otrzymujesz inny tensor wyjściowy. Wynika to z tego, że początkowe parametry modelu są domyślnie **losowane**. Oznacza to, że proces uczenia będzie **niedeterministryczny** - każde uruchomienie da inny wynik parametrów, które model się nauczy.
#
# Pozostało jeszcze dodanie nieliniowej transformacji do sieci, ale nie będziemy tego robić. Dodatkowo zamiast tworzyć osobny klasifikator na klasę, zastosujemy jeden klasyfikator. W tym celu zmieniemy funkcję kosztu. Do klasyfikacji wieloklasowej wykorzystamy funkcję **straty krzyżowej entropii**.
#
# $\text{loss} = -\frac{1}{N}\sum_{i}^{N}\log(\text{softmax}(x_{i}){y_{i}}) $, gdzie $N$ oznacza liczbę przypadków, $x_{i}$ wyjście z ostatniej warstwy $i$-tej instancji, $y_{i}$ klasę $i$-tej instancji.
#
# **Softmax** jest przekstałceniem nielinowym powszechnie używanym jako ostatnia warstwa sieci neuronowej służącej do klasyfikacji. Jej mocną stroną jest to, że suma wszystkich elementów tensora będących na jej wyjściu wynosi $1$. Dzięki temu możemy wyjście sieci interpretować jako przypisanie pseudoprawdopodbieństwa dla klasyfikacji dla danej próbki.
#
# Dla danego wektora $\mathbf x = (x_1, x_2, \ldots, x_i, \ldots, x_C)$ funkcja Softmax jest zdefiniowana jako:
# $\text{Softmax}(x_{i}) = \frac{\exp(x_{i})}{\sum_{j}^{C} \exp(x_{j})}$, gdzie $C$ oznacza liczbę klas.
#
# W tym zadaniu nie będziemy implementować tych funkcji samemu tylko wykorzystamy gotową implementację w bibliotece torch. Implementację znajdziemy w [`torch.nn.CrossEntropyLoss`](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html). Przyjmuje ona "surowe" wartości, dlatego że oblicza również funkcję **LogSoftmax**. Alternatywnie możemy nałożyć funkcję aktywacji LogSoftmax z modułu [`torch.nn.LogSoftmax`](https://pytorch.org/docs/stable/generated/torch.nn.LogSoftmax.html) i obliczyć negatywny logarytm funkcji wiarygodności (ang. *negative log likelihood*) [`torch.nn.NLLLoss`](https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html#torch.nn.NLLLoss). `torch.nn.NLLLoss` nie wykonuje operacji logarytmowania tylko oczekuje zlogarytmowanego wejścia.
#
# **LogSoftmax** wykorzystany jest tutaj nieprzypadkowo. Funkcja softmax w oryginalnej postaci nie jest odparna na wystąpienie niestabilności numerycznych. W przypadku liczenia entropii krzyżowej możemy wykorzystać skalę logarytmiczną do przeprowadzenia operacji. Dzięki przenesieniu obliczania logarytmu do funkcji Softmax możemy zastąpić dzielenie na różnicę logarytmów. czyli zamiast powyższej definicji funkcja LogSoftmax przyjmuję następującą postać:
#
# $\text{LogSoftmax}(x_{i}) = x_{i} - log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$
#
# Dodatkowo stosowany jest także trik polegający na zastąpieniu operacji $log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$ operacją **LogSumExp**, zdefiniowaną jako
#
# $\text{LogSumExp}(\mathbf x) = \max(\mathbf x) + log \bigg({\sum_{j}^{C} \exp(x_{j} - \max(\mathbf x))}\bigg)$.
#
# Pozwala to pozbyć się dużych wartości $x_{j}$ podczas obliczania $\exp$.

# %% [markdown]
# ## Algorytmy online i offline (`DataLoader`)
#
# Na poprzednich zajęciach zaimplementowałaś(eś) **algorytm offline** (alternatywnie batchowy lub deterministyczny, ang. *offline*, *batch*, *deterministic*) tzn. taki, który przetwarza od razu wszystkie dane. Jednakże implementując sieci neuronowe tworzymy często algorytmy **online** (alternatywnie stochastyczne, ang. *online*, *stochastic*), które przetwarzają dane w "kawałkach" lub wręcz mogą dostawać je "na bieżąco" bez konieczności posiadania wszystkcih danych przed uruchomieniem algorytmu. Są różne powody, dla których tak się robi, ale najczęstrzy jest taki, że przy głębszych architektrurach i bardziej złożonych obiektach (np. obrazach) byłoby fizycznie nie możliwe pomieścić te wszystkie dane w pamięci RAM lub VRAM (RAM na GPU) wraz z parametrami modelu.
#
# Liczbę próbek w algorytmach stochastycznych w sieciach neuronowych określa się jako **minibatch size** lub po prostu **batch size**. Przy czym określenie *batch size* nie odnosi się tutaj do algorytmów batchowych (operujących na całym zbiorze danych), tylko do algorytmów online/minibatch. Po prostu *batch size* jest określeniem krótszym (ale mniej poprawnym) niż *minibatch size*, stąd też powszechnie używa się tego pierwszego. Z tego też powodu czasami niektórzy używają określenia *batch* na *minibatch* - warto mieć to na uwadze przy komunikowaniu się z innymi osobami.
#
# Do zaimplementowania minibatchy wykorzystamy [`torch.utils.data.DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader). ***Zaimplementuj*** funkcję `to_dataloader`, która `X_train` i `y_train` oraz `X_test` i `y_test` umieści w dwóch osobnych instancjach klasy `DataLoader` z wielkością minibatacha równą `batch_size`

# %%
def to_dataloader(
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_test: torch.Tensor,
    y_test: torch.Tensor,
    batch_size: int = 32
) -> Tuple[DataLoader, DataLoader]:
    train_ds = TensorDataset(X_train, y_train)
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

    test_ds = TensorDataset(X_test, y_test)
    test_dl = DataLoader(test_ds, batch_size=batch_size)

    return train_dl, test_dl

# %% [markdown]
# ***Przetestuj*** implementację

# %%
train_loader, test_loader = to_dataloader(
    X_train=X_train,  y_train=y_train,
    X_test=X_test, y_test=y_test,
    batch_size=32
)

for sample in test_loader:
    print(sample)
# Out:
# [tensor([[5.1000, 3.8000, 1.9000, 0.4000],
#         [7.4000, 2.8000, 6.1000, 1.9000],
#         [4.6000, 3.2000, 1.4000, 0.2000],
#         [6.4000, 2.9000, 4.3000, 1.3000],
#         [7.3000, 2.9000, 6.3000, 1.8000],
#         [7.0000, 3.2000, 4.7000, 1.4000],
#         [5.1000, 2.5000, 3.0000, 1.1000],
#         [7.2000, 3.2000, 6.0000, 1.8000],
#         [6.7000, 2.5000, 5.8000, 1.8000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [6.1000, 3.0000, 4.9000, 1.8000],
#         [5.1000, 3.5000, 1.4000, 0.2000],
#         [6.9000, 3.2000, 5.7000, 2.3000],
#         [6.2000, 3.4000, 5.4000, 2.3000],
#         [6.0000, 3.4000, 4.5000, 1.6000],
#         [6.1000, 3.0000, 4.6000, 1.4000],
#         [6.8000, 3.0000, 5.5000, 2.1000],
#         [6.8000, 2.8000, 4.8000, 1.4000],
#         [5.7000, 2.5000, 5.0000, 2.0000],
#         [6.2000, 2.2000, 4.5000, 1.5000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [5.0000, 3.5000, 1.6000, 0.6000],
#         [6.7000, 3.3000, 5.7000, 2.5000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [5.6000, 2.7000, 4.2000, 1.3000],
#         [6.6000, 3.0000, 4.4000, 1.4000],
#         [5.9000, 3.0000, 5.1000, 1.8000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [6.7000, 3.1000, 5.6000, 2.4000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [4.6000, 3.4000, 1.4000, 0.3000],
#         [5.7000, 2.8000, 4.1000, 1.3000]], device='cuda:0'), tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1], device='cuda:0')]
# [tensor([[6.7000, 3.1000, 4.4000, 1.4000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [4.8000, 3.4000, 1.6000, 0.2000],
#         [5.2000, 3.4000, 1.4000, 0.2000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000],
#         [6.5000, 3.0000, 5.2000, 2.0000],
#         [6.5000, 2.8000, 4.6000, 1.5000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [4.9000, 3.1000, 1.5000, 0.2000],
#         [5.4000, 3.9000, 1.3000, 0.4000],
#         [6.5000, 3.0000, 5.8000, 2.2000],
#         [4.9000, 2.5000, 4.5000, 1.7000],
#         [6.1000, 2.8000, 4.7000, 1.2000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [5.0000, 3.0000, 1.6000, 0.2000],
#         [4.9000, 2.4000, 3.3000, 1.0000],
#         [6.9000, 3.1000, 5.1000, 2.3000],
#         [5.5000, 2.3000, 4.0000, 1.3000],
#         [5.6000, 3.0000, 4.5000, 1.5000],
#         [6.3000, 3.3000, 4.7000, 1.6000],
#         [5.6000, 2.8000, 4.9000, 2.0000],
#         [5.4000, 3.0000, 4.5000, 1.5000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [4.9000, 3.6000, 1.4000, 0.1000],
#         [6.0000, 2.2000, 4.0000, 1.0000],
#         [6.1000, 2.8000, 4.0000, 1.3000]], device='cuda:0'), tensor([1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0, 0, 1, 2, 1, 1, 1, 2, 1,
#         0, 0, 1, 1], device='cuda:0')]

# %% [markdown]
# ## Ewaluacja modelu - metryki
#
# ***Zaimplementuj*** funkcję `validate`, które dla danego modelu, funkcji straty i loadera zwróci średnią wartość funkcji straty oraz dokładność (ang. *accuracy*) dla danych z `dataloader`.

# %%
def count_correct(
    y_pred: torch.Tensor, y_true: torch.Tensor
) -> torch.Tensor:
    preds = torch.argmax(y_pred, dim=1)
    return (preds == y_true).float().sum()

def validate(
    model: nn.Module,
    loss_fn: torch.nn.CrossEntropyLoss,
    dataloader: DataLoader
) -> Tuple[torch.Tensor, torch.Tensor]:
    loss = 0
    correct = 0
    all = 0
    for X_batch, y_batch in dataloader:
        y_pred = model(X_batch)
        all += len(y_pred)
        loss += loss_fn(y_pred, y_batch).sum()
        correct += count_correct(y_pred, y_batch)
    return loss / all, correct / all

# %% [markdown]
# ***Przetestuj*** swoją implementację

# %%
loss_fn = torch.nn.CrossEntropyLoss()
val_train, acc_train = validate(model, loss_fn, test_loader)
print(val_train, acc_train)
# Out:
# tensor(0.1242, device='cuda:0', grad_fn=<DivBackward0>) tensor(0.3333, device='cuda:0')

# %% [markdown]
# ## Uczenie
#
# Przed uzupełnieniem poniżej implementacji została nam jeszcze jedna istotna kwestia do poruszenia. Otóż dot tej pory aktualizację parametrów dokonywaliśmy wg prostej formuły - mnożyliśmy gradienty przez współczynnik uczenia (ang. *learning rate*) i odejmowalismy od parametrów. Jednakże do uczenia sieci neuronowych sotsujemy często optymalizatory (ang. *optimiser*), które mogą implementować różne podejścia do uakualiniania parameterów modelu. Wykorzystamy tutaj algorytm **Adam** (ang. *adaptive moment estimation*), który dostosowuje współczynnik uczenia do poszczególnych parametrów i jest często optimizatorem pierwszego wyboru.
#
# ***Uzupełnij i przetestuj*** poniższą implementację uczenia modelu. Porównaj jej skuteczność z tą, którą zaimplementowałeś(aś) na laboratorium 2.

# %%
def fit(
    model: nn.Module, optimiser: optim.Optimizer,
    loss_fn: torch.nn.CrossEntropyLoss, train_dl: DataLoader,
    val_dl: DataLoader, epochs: int,
    print_metrics: bool = True
) -> dict:
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}
    for epoch in range(epochs):
        model.train()  # Przełączenie na tryb uczenia modelu
        for X_batch, y_batch in train_dl:
            y_pred = model(X_batch)  # Uzyskanie pseudoprawdopodobieństw dla próbek z minibatcha
            loss = loss_fn(y_pred, y_batch)  # Policzenie funkcji straty

            loss.backward()  # Wsteczna propagacja
            optimiser.step()  # Aktualizacja parametrów modelu
            optimiser.zero_grad()  # Wyzerowanie gradientów

        if print_metrics:
            model.eval()  # Przełączenie na tryb ewaluacji modelu
            with torch.no_grad():
                train_loss, train_acc = validate(model, loss_fn, train_dl)
                val_loss, val_acc = validate(model, loss_fn, val_dl)
                history['train_loss'].append(train_loss.item())
                history['train_acc'].append(train_acc.item())
                history['val_loss'].append(val_loss.item())
                history['val_acc'].append(val_acc.item())
                print(
                    f"Epoch {epoch}: "
                    f"train loss = {train_loss:.3f} (acc: {train_acc:.3f}), "
                    f"validation loss = {val_loss:.3f} (acc: {val_acc:.3f})"
                )

    model.eval()  # Przełączenie na tryb ewaluacji modelu
    return history

train_dl, test_dl = to_dataloader(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    batch_size=32
)
perceptron = Perceptron().cuda()
optimiser = optim.Adam(perceptron.parameters(), lr=0.001)
loss_fn = torch.nn.CrossEntropyLoss()
history = fit(
    model=perceptron, optimiser=optimiser, loss_fn=loss_fn,
    train_dl=train_dl, val_dl=test_dl, epochs=50
)
# Out:
# Epoch 0: train loss = 0.096 (acc: 0.333), validation loss = 0.094 (acc: 0.333)
# Epoch 1: train loss = 0.093 (acc: 0.333), validation loss = 0.092 (acc: 0.333)
# Epoch 2: train loss = 0.092 (acc: 0.333), validation loss = 0.091 (acc: 0.333)
# Epoch 3: train loss = 0.091 (acc: 0.333), validation loss = 0.089 (acc: 0.333)
# Epoch 4: train loss = 0.089 (acc: 0.333), validation loss = 0.088 (acc: 0.333)
# Epoch 5: train loss = 0.087 (acc: 0.333), validation loss = 0.086 (acc: 0.333)
# Epoch 6: train loss = 0.088 (acc: 0.333), validation loss = 0.085 (acc: 0.333)
# Epoch 7: train loss = 0.088 (acc: 0.333), validation loss = 0.084 (acc: 0.333)
# Epoch 8: train loss = 0.084 (acc: 0.333), validation loss = 0.083 (acc: 0.333)
# Epoch 9: train loss = 0.082 (acc: 0.333), validation loss = 0.082 (acc: 0.333)
# Epoch 10: train loss = 0.082 (acc: 0.333), validation loss = 0.080 (acc: 0.333)
# Epoch 11: train loss = 0.081 (acc: 0.333), validation loss = 0.079 (acc: 0.333)
# Epoch 12: train loss = 0.080 (acc: 0.333), validation loss = 0.078 (acc: 0.333)
# Epoch 13: train loss = 0.079 (acc: 0.333), validation loss = 0.077 (acc: 0.333)
# Epoch 14: train loss = 0.077 (acc: 0.333), validation loss = 0.076 (acc: 0.333)
# Epoch 15: train loss = 0.077 (acc: 0.333), validation loss = 0.075 (acc: 0.333)
# Epoch 16: train loss = 0.076 (acc: 0.333), validation loss = 0.074 (acc: 0.333)
# Epoch 17: train loss = 0.073 (acc: 0.333), validation loss = 0.073 (acc: 0.333)
# Epoch 18: train loss = 0.074 (acc: 0.322), validation loss = 0.072 (acc: 0.333)
# Epoch 19: train loss = 0.073 (acc: 0.322), validation loss = 0.071 (acc: 0.333)
# Epoch 20: train loss = 0.071 (acc: 0.322), validation loss = 0.070 (acc: 0.333)
# Epoch 21: train loss = 0.070 (acc: 0.322), validation loss = 0.069 (acc: 0.333)
# Epoch 22: train loss = 0.067 (acc: 0.322), validation loss = 0.068 (acc: 0.333)
# Epoch 23: train loss = 0.067 (acc: 0.322), validation loss = 0.067 (acc: 0.333)
# Epoch 24: train loss = 0.067 (acc: 0.322), validation loss = 0.066 (acc: 0.333)
# Epoch 25: train loss = 0.067 (acc: 0.322), validation loss = 0.065 (acc: 0.333)
# Epoch 26: train loss = 0.065 (acc: 0.322), validation loss = 0.064 (acc: 0.333)
# Epoch 27: train loss = 0.064 (acc: 0.322), validation loss = 0.063 (acc: 0.333)
# Epoch 28: train loss = 0.064 (acc: 0.322), validation loss = 0.062 (acc: 0.333)
# Epoch 29: train loss = 0.062 (acc: 0.333), validation loss = 0.061 (acc: 0.333)
# Epoch 30: train loss = 0.061 (acc: 0.333), validation loss = 0.060 (acc: 0.333)
# Epoch 31: train loss = 0.060 (acc: 0.333), validation loss = 0.059 (acc: 0.333)
# Epoch 32: train loss = 0.059 (acc: 0.333), validation loss = 0.058 (acc: 0.333)
# Epoch 33: train loss = 0.058 (acc: 0.333), validation loss = 0.057 (acc: 0.333)
# Epoch 34: train loss = 0.057 (acc: 0.333), validation loss = 0.056 (acc: 0.333)
# Epoch 35: train loss = 0.055 (acc: 0.333), validation loss = 0.055 (acc: 0.333)
# Epoch 36: train loss = 0.055 (acc: 0.333), validation loss = 0.054 (acc: 0.333)
# Epoch 37: train loss = 0.053 (acc: 0.333), validation loss = 0.053 (acc: 0.333)
# Epoch 38: train loss = 0.053 (acc: 0.333), validation loss = 0.052 (acc: 0.333)
# Epoch 39: train loss = 0.053 (acc: 0.333), validation loss = 0.051 (acc: 0.333)
# Epoch 40: train loss = 0.051 (acc: 0.333), validation loss = 0.050 (acc: 0.333)
# Epoch 41: train loss = 0.051 (acc: 0.333), validation loss = 0.049 (acc: 0.333)
# Epoch 42: train loss = 0.049 (acc: 0.333), validation loss = 0.049 (acc: 0.333)
# Epoch 43: train loss = 0.048 (acc: 0.333), validation loss = 0.048 (acc: 0.333)
# Epoch 44: train loss = 0.048 (acc: 0.333), validation loss = 0.047 (acc: 0.333)
# Epoch 45: train loss = 0.047 (acc: 0.333), validation loss = 0.046 (acc: 0.333)
# Epoch 46: train loss = 0.045 (acc: 0.333), validation loss = 0.045 (acc: 0.333)
# Epoch 47: train loss = 0.045 (acc: 0.333), validation loss = 0.044 (acc: 0.333)
# Epoch 48: train loss = 0.045 (acc: 0.333), validation loss = 0.044 (acc: 0.333)
# Epoch 49: train loss = 0.043 (acc: 0.333), validation loss = 0.043 (acc: 0.333)

# %% [markdown]
# ***Uzupełnij*** funkcję `fit`, aby ta mogła logować metryki (*loss*, *accuracy*) per epokę. Po zebraniu historii uczenia ***przedstaw*** następujące wykresy:
# - Wykres wartości funkcji kosztu w zależności od epoki uczenia dla zbioru uczącego i testowego
# - Wykres wartości metryki *accuracy* w zależności od epoki uczenia dla zbioru uczącego i testowego
#
# Metryki dla obu zbiorów przedstaw na jednym wykresie jako serie. ***Uzupełnij*** etykiety osi i tytuły wykresów.

# %% [markdown]
# ***Popraw*** model, tak aby otrzymać dokładność na zbiorze testowym wynoszącą co najmniej 90%. W tym celu dobierz odpowiedni współczynnik uczenia i liczbę epok.
# Do porównania badanych hiperparametrów użyj zbioru walidacyjnego. Podziel zbiór testowy na dwie równe części, jeden który będzie służyć do walidacji hiperparametrów, a drugi, który będzie służył do ewaluacji znalezionej najlepszej pary hiperparametrów. W tym celu możesz wykorzystać funkcję `torch.utils.data.random_split` z ustawionym parametrem `generator=torch.Generator().manual_seed(1)`. Przedstaw równiez wykresy o których mowa punkcie powyżej tym razem z uwzględniem trzech zbiorów (uczącego, walidacyjnego i testowego)

# %% [markdown]
# ## Rozwiązania zadań

# %% [markdown]
# #### Zadanie 1:
# - Wykres wartości funkcji kosztu w zależności od epoki uczenia dla zbioru uczącego i testowego
# - Wykres wartości metryki accuracy w zależności od epoki uczenia dla zbioru uczącego i testowego

# %%
import matplotlib.pyplot as plt

epochs_range = range(len(history['train_loss']))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
ax1.plot(epochs_range, history['train_loss'], label='Zbiór uczący', color='steelblue')
ax1.plot(epochs_range, history['val_loss'], label='Zbiór testowy', color='tomato')
ax1.set_title('Funkcja kosztu w zależności od epoki')
ax1.set_xlabel('Epoka')
ax1.set_ylabel('Loss (CrossEntropy)')
ax1.legend()
ax1.grid(True)

# Accuracy plot
ax2.plot(epochs_range, history['train_acc'], label='Zbiór uczący', color='steelblue')
ax2.plot(epochs_range, history['val_acc'], label='Zbiór testowy', color='tomato')
ax2.set_title('Dokładność (accuracy) w zależności od epoki')
ax2.set_xlabel('Epoka')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Zadanie 2:
# Podziel zbiór testowy na dwie równe części, jeden który będzie służyć do walidacji hiperparametrów, a drugi, który będzie służył do ewaluacji znalezionej najlepszej pary hiperparametrów. W tym celu możesz wykorzystać funkcję `torch.utils.data.random_split` z ustawionym parametrem `generator=torch.Generator().manual_seed(1)`.

# %% [markdown]
# - podział zbioru na walidacyjny i testowy (50/50)

# %%
from torch.utils.data import random_split

test_ds_full = TensorDataset(X_test, y_test)
val_size = len(test_ds_full) // 2
test_size = len(test_ds_full) - val_size
val_ds, final_test_ds = random_split(
    test_ds_full, [val_size, test_size],
    generator=torch.Generator().manual_seed(1)
)
val_dl = DataLoader(val_ds, batch_size=32)
final_test_dl = DataLoader(final_test_ds, batch_size=32)

# %% [markdown]
# - Siatka hierparametrów

# %%
learning_rates = [0.01, 0.001, 0.0001]
epochs_list = [50, 100, 200]

best_val_acc = 0
best_lr = None
best_epochs = None

for lr in learning_rates:
    for epochs in epochs_list:
        model_hp = Perceptron().cuda()
        opt_hp = optim.Adam(model_hp.parameters(), lr=lr)
        loss_fn_hp = torch.nn.CrossEntropyLoss()
        fit(model_hp, opt_hp, loss_fn_hp, train_dl, val_dl, epochs, print_metrics=False)
        with torch.no_grad():
            _, val_acc = validate(model_hp, loss_fn_hp, val_dl)
        print(f'lr={lr}, epochs={epochs}: val_acc={val_acc:.3f}')
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_lr = lr
            best_epochs = epochs

print(f'\nNajlepsze hiperparametry: lr={best_lr}, epochs={best_epochs}, val_acc={best_val_acc:.3f}')
# Out:
# lr=0.01, epochs=50: val_acc=0.967
# lr=0.01, epochs=100: val_acc=0.967
# lr=0.01, epochs=200: val_acc=1.000
# lr=0.001, epochs=50: val_acc=0.400
# lr=0.001, epochs=100: val_acc=0.533
# lr=0.001, epochs=200: val_acc=0.567
# lr=0.0001, epochs=50: val_acc=0.333
# lr=0.0001, epochs=100: val_acc=0.333
# lr=0.0001, epochs=200: val_acc=0.400
#
# Najlepsze hiperparametry: lr=0.01, epochs=200, val_acc=1.000

# %% [markdown]
# - Trenowanie finalnego modelu z najlepszymi hiperparametrami

# %%
best_model = Perceptron().cuda()
best_opt = optim.Adam(best_model.parameters(), lr=best_lr)
best_loss_fn = torch.nn.CrossEntropyLoss()
best_history = fit(
    model=best_model, optimiser=best_opt, loss_fn=best_loss_fn,
    train_dl=train_dl, val_dl=val_dl, epochs=best_epochs
)

with torch.no_grad():
    _, test_acc = validate(best_model, best_loss_fn, final_test_dl)
print(f'\nDokładność na zbiorze testowym (finalnym): {test_acc:.3f}')
# Out:
# Epoch 0: train loss = 0.096 (acc: 0.267), validation loss = 0.106 (acc: 0.267)
# Epoch 1: train loss = 0.079 (acc: 0.011), validation loss = 0.087 (acc: 0.000)
# Epoch 2: train loss = 0.068 (acc: 0.000), validation loss = 0.072 (acc: 0.000)
# Epoch 3: train loss = 0.058 (acc: 0.044), validation loss = 0.059 (acc: 0.000)
# Epoch 4: train loss = 0.051 (acc: 0.256), validation loss = 0.050 (acc: 0.300)
# Epoch 5: train loss = 0.046 (acc: 0.322), validation loss = 0.043 (acc: 0.333)
# Epoch 6: train loss = 0.042 (acc: 0.544), validation loss = 0.039 (acc: 0.633)
# Epoch 7: train loss = 0.041 (acc: 0.456), validation loss = 0.037 (acc: 0.633)
# Epoch 8: train loss = 0.040 (acc: 0.344), validation loss = 0.036 (acc: 0.433)
# Epoch 9: train loss = 0.040 (acc: 0.333), validation loss = 0.036 (acc: 0.400)
# Epoch 10: train loss = 0.040 (acc: 0.333), validation loss = 0.035 (acc: 0.400)
# Epoch 11: train loss = 0.038 (acc: 0.333), validation loss = 0.034 (acc: 0.400)
# Epoch 12: train loss = 0.037 (acc: 0.333), validation loss = 0.033 (acc: 0.433)
# Epoch 13: train loss = 0.035 (acc: 0.367), validation loss = 0.032 (acc: 0.433)
# Epoch 14: train loss = 0.034 (acc: 0.433), validation loss = 0.031 (acc: 0.600)
# Epoch 15: train loss = 0.033 (acc: 0.478), validation loss = 0.031 (acc: 0.667)
# Epoch 16: train loss = 0.032 (acc: 0.522), validation loss = 0.031 (acc: 0.667)
# Epoch 17: train loss = 0.032 (acc: 0.533), validation loss = 0.030 (acc: 0.667)
# Epoch 18: train loss = 0.031 (acc: 0.567), validation loss = 0.030 (acc: 0.667)
# Epoch 19: train loss = 0.030 (acc: 0.589), validation loss = 0.029 (acc: 0.733)
# Epoch 20: train loss = 0.029 (acc: 0.644), validation loss = 0.028 (acc: 0.800)
# Epoch 21: train loss = 0.029 (acc: 0.722), validation loss = 0.027 (acc: 0.800)
# Epoch 22: train loss = 0.028 (acc: 0.722), validation loss = 0.027 (acc: 0.867)
# Epoch 23: train loss = 0.027 (acc: 0.744), validation loss = 0.026 (acc: 0.900)
# Epoch 24: train loss = 0.027 (acc: 0.756), validation loss = 0.026 (acc: 0.900)
# Epoch 25: train loss = 0.026 (acc: 0.767), validation loss = 0.025 (acc: 0.933)
# Epoch 26: train loss = 0.026 (acc: 0.800), validation loss = 0.025 (acc: 0.933)
# Epoch 27: train loss = 0.025 (acc: 0.844), validation loss = 0.024 (acc: 0.933)
# Epoch 28: train loss = 0.025 (acc: 0.844), validation loss = 0.024 (acc: 0.933)
# Epoch 29: train loss = 0.024 (acc: 0.844), validation loss = 0.024 (acc: 0.933)
# Epoch 30: train loss = 0.024 (acc: 0.844), validation loss = 0.023 (acc: 0.933)
# Epoch 31: train loss = 0.023 (acc: 0.844), validation loss = 0.023 (acc: 0.933)
# Epoch 32: train loss = 0.023 (acc: 0.844), validation loss = 0.023 (acc: 0.933)
# Epoch 33: train loss = 0.023 (acc: 0.778), validation loss = 0.022 (acc: 0.933)
# Epoch 34: train loss = 0.022 (acc: 0.789), validation loss = 0.022 (acc: 0.933)
# Epoch 35: train loss = 0.022 (acc: 0.778), validation loss = 0.022 (acc: 0.933)
# Epoch 36: train loss = 0.022 (acc: 0.822), validation loss = 0.021 (acc: 0.933)
# Epoch 37: train loss = 0.021 (acc: 0.856), validation loss = 0.021 (acc: 0.933)
# Epoch 38: train loss = 0.021 (acc: 0.856), validation loss = 0.021 (acc: 0.933)
# Epoch 39: train loss = 0.021 (acc: 0.833), validation loss = 0.021 (acc: 0.933)
# Epoch 40: train loss = 0.021 (acc: 0.833), validation loss = 0.020 (acc: 0.933)
# Epoch 41: train loss = 0.020 (acc: 0.844), validation loss = 0.020 (acc: 0.933)
# Epoch 42: train loss = 0.020 (acc: 0.856), validation loss = 0.020 (acc: 0.933)
# Epoch 43: train loss = 0.020 (acc: 0.856), validation loss = 0.020 (acc: 0.933)
# Epoch 44: train loss = 0.020 (acc: 0.856), validation loss = 0.020 (acc: 0.933)
# Epoch 45: train loss = 0.020 (acc: 0.856), validation loss = 0.019 (acc: 0.933)
# Epoch 46: train loss = 0.019 (acc: 0.856), validation loss = 0.019 (acc: 0.933)
# Epoch 47: train loss = 0.019 (acc: 0.856), validation loss = 0.019 (acc: 0.933)
# Epoch 48: train loss = 0.019 (acc: 0.844), validation loss = 0.019 (acc: 0.933)
# Epoch 49: train loss = 0.019 (acc: 0.844), validation loss = 0.019 (acc: 0.933)
# Epoch 50: train loss = 0.018 (acc: 0.844), validation loss = 0.018 (acc: 0.933)
# Epoch 51: train loss = 0.019 (acc: 0.856), validation loss = 0.018 (acc: 0.933)
# Epoch 52: train loss = 0.018 (acc: 0.856), validation loss = 0.018 (acc: 0.933)
# Epoch 53: train loss = 0.018 (acc: 0.856), validation loss = 0.018 (acc: 0.933)
# Epoch 54: train loss = 0.018 (acc: 0.844), validation loss = 0.018 (acc: 0.933)
# Epoch 55: train loss = 0.018 (acc: 0.856), validation loss = 0.018 (acc: 0.933)
# Epoch 56: train loss = 0.018 (acc: 0.856), validation loss = 0.018 (acc: 0.933)
# Epoch 57: train loss = 0.018 (acc: 0.844), validation loss = 0.017 (acc: 0.933)
# Epoch 58: train loss = 0.017 (acc: 0.867), validation loss = 0.017 (acc: 0.933)
# Epoch 59: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 60: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 61: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 62: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 63: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 64: train loss = 0.017 (acc: 0.856), validation loss = 0.017 (acc: 0.933)
# Epoch 65: train loss = 0.017 (acc: 0.867), validation loss = 0.017 (acc: 0.933)
# Epoch 66: train loss = 0.016 (acc: 0.889), validation loss = 0.016 (acc: 0.933)
# Epoch 67: train loss = 0.016 (acc: 0.900), validation loss = 0.016 (acc: 0.933)
# Epoch 68: train loss = 0.016 (acc: 0.856), validation loss = 0.016 (acc: 0.933)
# Epoch 69: train loss = 0.016 (acc: 0.867), validation loss = 0.016 (acc: 0.933)
# Epoch 70: train loss = 0.016 (acc: 0.856), validation loss = 0.016 (acc: 0.933)
# Epoch 71: train loss = 0.016 (acc: 0.856), validation loss = 0.016 (acc: 0.933)
# Epoch 72: train loss = 0.016 (acc: 0.867), validation loss = 0.016 (acc: 0.933)
# Epoch 73: train loss = 0.016 (acc: 0.867), validation loss = 0.016 (acc: 0.933)
# Epoch 74: train loss = 0.016 (acc: 0.856), validation loss = 0.016 (acc: 0.933)
# Epoch 75: train loss = 0.015 (acc: 0.900), validation loss = 0.016 (acc: 0.933)
# Epoch 76: train loss = 0.016 (acc: 0.933), validation loss = 0.015 (acc: 0.933)
# Epoch 77: train loss = 0.015 (acc: 0.900), validation loss = 0.015 (acc: 0.933)
# Epoch 78: train loss = 0.015 (acc: 0.878), validation loss = 0.015 (acc: 0.933)
# Epoch 79: train loss = 0.015 (acc: 0.878), validation loss = 0.015 (acc: 0.933)
# Epoch 80: train loss = 0.015 (acc: 0.867), validation loss = 0.015 (acc: 0.933)
# Epoch 81: train loss = 0.015 (acc: 0.867), validation loss = 0.015 (acc: 0.933)
# Epoch 82: train loss = 0.015 (acc: 0.867), validation loss = 0.015 (acc: 0.933)
# Epoch 83: train loss = 0.015 (acc: 0.889), validation loss = 0.015 (acc: 0.933)
# Epoch 84: train loss = 0.015 (acc: 0.944), validation loss = 0.015 (acc: 0.967)
# Epoch 85: train loss = 0.015 (acc: 0.944), validation loss = 0.015 (acc: 0.967)
# Epoch 86: train loss = 0.015 (acc: 0.911), validation loss = 0.015 (acc: 0.933)
# Epoch 87: train loss = 0.014 (acc: 0.889), validation loss = 0.014 (acc: 0.933)
# Epoch 88: train loss = 0.014 (acc: 0.900), validation loss = 0.014 (acc: 0.933)
# Epoch 89: train loss = 0.014 (acc: 0.900), validation loss = 0.014 (acc: 0.933)
# Epoch 90: train loss = 0.014 (acc: 0.900), validation loss = 0.014 (acc: 0.933)
# Epoch 91: train loss = 0.014 (acc: 0.922), validation loss = 0.014 (acc: 0.967)
# Epoch 92: train loss = 0.014 (acc: 0.944), validation loss = 0.014 (acc: 0.967)
# Epoch 93: train loss = 0.014 (acc: 0.922), validation loss = 0.014 (acc: 0.933)
# Epoch 94: train loss = 0.014 (acc: 0.922), validation loss = 0.014 (acc: 0.933)
# Epoch 95: train loss = 0.014 (acc: 0.911), validation loss = 0.014 (acc: 0.933)
# Epoch 96: train loss = 0.014 (acc: 0.956), validation loss = 0.014 (acc: 0.967)
# Epoch 97: train loss = 0.014 (acc: 0.956), validation loss = 0.014 (acc: 0.967)
# Epoch 98: train loss = 0.014 (acc: 0.911), validation loss = 0.014 (acc: 0.967)
# Epoch 99: train loss = 0.014 (acc: 0.922), validation loss = 0.014 (acc: 0.933)
# Epoch 100: train loss = 0.014 (acc: 0.956), validation loss = 0.014 (acc: 0.967)
# Epoch 101: train loss = 0.013 (acc: 0.956), validation loss = 0.014 (acc: 0.967)
# Epoch 102: train loss = 0.014 (acc: 0.944), validation loss = 0.013 (acc: 0.967)
# Epoch 103: train loss = 0.014 (acc: 0.956), validation loss = 0.013 (acc: 0.967)
# Epoch 104: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 105: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 106: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 107: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 108: train loss = 0.013 (acc: 0.922), validation loss = 0.013 (acc: 0.967)
# Epoch 109: train loss = 0.013 (acc: 0.922), validation loss = 0.013 (acc: 0.933)
# Epoch 110: train loss = 0.013 (acc: 0.922), validation loss = 0.013 (acc: 0.933)
# Epoch 111: train loss = 0.013 (acc: 0.944), validation loss = 0.013 (acc: 0.967)
# Epoch 112: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 113: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 114: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 115: train loss = 0.013 (acc: 0.967), validation loss = 0.013 (acc: 0.967)
# Epoch 116: train loss = 0.013 (acc: 0.944), validation loss = 0.013 (acc: 0.967)
# Epoch 117: train loss = 0.013 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 118: train loss = 0.013 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 119: train loss = 0.013 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 120: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 121: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 122: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 123: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 124: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 125: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 126: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 127: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 128: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 129: train loss = 0.012 (acc: 0.944), validation loss = 0.012 (acc: 0.967)
# Epoch 130: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 131: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 132: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 133: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 134: train loss = 0.012 (acc: 0.967), validation loss = 0.012 (acc: 0.967)
# Epoch 135: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 136: train loss = 0.012 (acc: 0.978), validation loss = 0.012 (acc: 0.967)
# Epoch 137: train loss = 0.012 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 138: train loss = 0.012 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 139: train loss = 0.012 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 140: train loss = 0.012 (acc: 0.967), validation loss = 0.011 (acc: 0.967)
# Epoch 141: train loss = 0.012 (acc: 0.967), validation loss = 0.011 (acc: 0.967)
# Epoch 142: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 143: train loss = 0.012 (acc: 0.967), validation loss = 0.011 (acc: 0.967)
# Epoch 144: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 145: train loss = 0.011 (acc: 0.944), validation loss = 0.011 (acc: 0.967)
# Epoch 146: train loss = 0.011 (acc: 0.944), validation loss = 0.011 (acc: 0.967)
# Epoch 147: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 148: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 149: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 150: train loss = 0.011 (acc: 0.967), validation loss = 0.011 (acc: 0.967)
# Epoch 151: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 152: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 153: train loss = 0.011 (acc: 0.967), validation loss = 0.011 (acc: 0.967)
# Epoch 154: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 155: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 156: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 157: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 158: train loss = 0.011 (acc: 0.978), validation loss = 0.011 (acc: 0.967)
# Epoch 159: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 160: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 161: train loss = 0.011 (acc: 0.967), validation loss = 0.010 (acc: 0.967)
# Epoch 162: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 163: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 164: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 165: train loss = 0.011 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 166: train loss = 0.011 (acc: 0.956), validation loss = 0.010 (acc: 0.967)
# Epoch 167: train loss = 0.011 (acc: 0.944), validation loss = 0.010 (acc: 1.000)
# Epoch 168: train loss = 0.010 (acc: 0.956), validation loss = 0.010 (acc: 0.967)
# Epoch 169: train loss = 0.010 (acc: 0.944), validation loss = 0.010 (acc: 1.000)
# Epoch 170: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 171: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 172: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 173: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 174: train loss = 0.010 (acc: 0.956), validation loss = 0.010 (acc: 0.967)
# Epoch 175: train loss = 0.010 (acc: 0.944), validation loss = 0.010 (acc: 1.000)
# Epoch 176: train loss = 0.010 (acc: 0.944), validation loss = 0.010 (acc: 1.000)
# Epoch 177: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 178: train loss = 0.010 (acc: 0.967), validation loss = 0.010 (acc: 0.967)
# Epoch 179: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 180: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 181: train loss = 0.010 (acc: 0.978), validation loss = 0.010 (acc: 0.967)
# Epoch 182: train loss = 0.010 (acc: 0.967), validation loss = 0.010 (acc: 1.000)
# Epoch 183: train loss = 0.010 (acc: 0.967), validation loss = 0.010 (acc: 1.000)
# Epoch 184: train loss = 0.010 (acc: 0.956), validation loss = 0.010 (acc: 1.000)
# Epoch 185: train loss = 0.010 (acc: 0.967), validation loss = 0.010 (acc: 1.000)
# Epoch 186: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 187: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 188: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 0.967)
# Epoch 189: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 0.967)
# Epoch 190: train loss = 0.010 (acc: 0.956), validation loss = 0.009 (acc: 1.000)
# Epoch 191: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 192: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 193: train loss = 0.010 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 194: train loss = 0.010 (acc: 0.944), validation loss = 0.009 (acc: 1.000)
# Epoch 195: train loss = 0.010 (acc: 0.956), validation loss = 0.009 (acc: 1.000)
# Epoch 196: train loss = 0.009 (acc: 0.956), validation loss = 0.009 (acc: 1.000)
# Epoch 197: train loss = 0.009 (acc: 0.967), validation loss = 0.009 (acc: 1.000)
# Epoch 198: train loss = 0.009 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
# Epoch 199: train loss = 0.009 (acc: 0.978), validation loss = 0.009 (acc: 1.000)
#
# Dokładność na zbiorze testowym (finalnym): 0.933

# %% [markdown]
# #### Zadanie 3:
# Przedstaw równiez wykresy o których mowa punkcie powyżej tym razem z uwzględniem trzech zbiorów (uczącego, walidacyjnego i testowego)
# - Wykres wartości funkcji kosztu w zależności od epoki uczenia dla zbioru uczącego, walidacyjnego i testowego
# - Wykres wartości metryki accuracy w zależności od epoki uczenia dla zbioru uczącego, walidacyjnego i testowego

# %%
train_hist = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': [], 'test_loss': [], 'test_acc': []}

final_model = Perceptron().cuda()
final_opt = optim.Adam(final_model.parameters(), lr=best_lr)
final_loss_fn = torch.nn.CrossEntropyLoss()

for epoch in range(best_epochs):
    final_model.train()
    for X_batch, y_batch in train_dl:
        y_pred = final_model(X_batch)
        loss = final_loss_fn(y_pred, y_batch)
        loss.backward()
        final_opt.step()
        final_opt.zero_grad()

    final_model.eval()
    with torch.no_grad():
        tr_l, tr_a = validate(final_model, final_loss_fn, train_dl)
        va_l, va_a = validate(final_model, final_loss_fn, val_dl)
        te_l, te_a = validate(final_model, final_loss_fn, final_test_dl)
        train_hist['train_loss'].append(tr_l.item())
        train_hist['train_acc'].append(tr_a.item())
        train_hist['val_loss'].append(va_l.item())
        train_hist['val_acc'].append(va_a.item())
        train_hist['test_loss'].append(te_l.item())
        train_hist['test_acc'].append(te_a.item())

epochs_range = range(best_epochs)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(epochs_range, train_hist['train_loss'], label='Uczący', color='steelblue')
ax1.plot(epochs_range, train_hist['val_loss'], label='Walidacyjny', color='orange')
ax1.plot(epochs_range, train_hist['test_loss'], label='Testowy', color='tomato')
ax1.set_title('Funkcja kosztu w zależności od epoki')
ax1.set_xlabel('Epoka')
ax1.set_ylabel('Loss (CrossEntropy)')
ax1.legend()
ax1.grid(True)

ax2.plot(epochs_range, train_hist['train_acc'], label='Uczący', color='steelblue')
ax2.plot(epochs_range, train_hist['val_acc'], label='Walidacyjny', color='orange')
ax2.plot(epochs_range, train_hist['test_acc'], label='Testowy', color='tomato')
ax2.axhline(y=0.9, color='green', linestyle='--', alpha=0.7, label='Cel: 90%')
ax2.set_title('Dokładność (accuracy) w zależności od epoki')
ax2.set_xlabel('Epoka')
ax2.set_ylabel('Accuracy')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()

print(f'\nFinalna dokładność na zbiorze testowym: {train_hist["test_acc"][-1]:.3f}')
# Out:
# Finalna dokładność na zbiorze testowym: 1.000
